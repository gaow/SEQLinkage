# %%
import sys
import os.path
import glob
import pandas as pd
import numpy as np
import pickle
from SEQLinkage.linkage import *

# %%
fam_vcf='../data/wg20220316/fam17_vcf.pickle'
fam_path='../data/new_trim_ped_famless17_no:xx.fam'
if os.path.isfile(fam_vcf):
    with open(fam_vcf, 'rb') as handle:
        fam17_vcf = pickle.load(handle)
fam17 = pd.read_csv(fam_path,delim_whitespace=True,header=None,names=['fid','iid','fathid','mothid','sex','ad'])
fam17.index = list(fam17.iid)
fam17.ad[fam17.ad==-9]=0
fam17_d = {}
cutoff=0.05
for i in fam17.fid.unique():
    fam17_d[i] = fam17[fam17.fid==i]
# Out:
# /tmp/2440590.1.high_mem.q/ipykernel_38000/2986720832.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fam17.ad[fam17.ad==-9]=0

# %%
inputs=glob.glob('../data/wg20220316/chr22test/tmp/CACHE/chr22test*.pickle')

# %%
for i in inputs:
    file=i[:-7]
    print(file)
    output=file+'cutoff'+str(cutoff)+'unimputed.input'
    if os.path.isfile(output):
        print('exist! jump',output,file=sys.stderr)
    else:
        print('create input',output,file=sys.stdout)
        with open(file+'.pickle', 'rb') as handle:
            genes = pickle.load(handle)
        gene_variants,gene_fam_haps = format_haps_bunch(genes,fam17_d,fam17_vcf,cutoff)
        with open(file+'cutoff'+str(cutoff)+'unimputed.input','wb') as handle:
            pickle.dump([gene_variants,gene_fam_haps], handle, protocol=pickle.HIGHEST_PROTOCOL)

    output_file=output[:-6]+'.lods'
    if os.path.isfile(output_file):
        print('exist! jump',output_file,file=sys.stderr)
    else:
        print('create input',output_file,file=sys.stdout)
        with open(output, 'rb') as handle:
            gene_variants,gene_fam_haps = pickle.load(handle) 
        afreqs = []
        for k in gene_fam_haps.keys():
            variants= gene_variants[k]
            variants=variants.freqs[variants.uniq]
            afreqs.append(list(variants.round(decimals=3)))
        res = parallel_lods(gene_fam_haps.values(),afreqs,np.arange(0,0.5,0.05))
        with open(output_file,'wb') as handle:
            pickle.dump(res, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test24
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test23
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test23cutoff0.05unimputed.input
# exist! jump ../data/wg20220316/chr22test/tmp/CACHE/chr22test24cutoff0.05unimputed.input
# exist! jump ../data/wg20220316/chr22test/tmp/CACHE/chr22test24cutoff0.05unimputed.lods
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test23cutoff0.05unimputed.lods
# 3815.2759209126234
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test22
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test22cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test22cutoff0.05unimputed.lods
# 2975.9615220054984
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test21
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test21cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test21cutoff0.05unimputed.lods
# 3550.831952303648
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test20
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test20cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test20cutoff0.05unimputed.lods
# 2697.201189249754
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test19
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test19cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test19cutoff0.05unimputed.lods
# 1159.5177156180143
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test18
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test18cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test18cutoff0.05unimputed.lods
# 918.2032298892736
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test17
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test17cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test17cutoff0.05unimputed.lods
# 1525.852048367262
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test16
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test16cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test16cutoff0.05unimputed.lods
# 862.629325337708
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test15
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test15cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test15cutoff0.05unimputed.lods
# 1026.3272412791848
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test14
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test14cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test14cutoff0.05unimputed.lods
# 1444.2991509884596
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test13
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test13cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test13cutoff0.05unimputed.lods
# 2651.569228731096
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test12
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test12cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test12cutoff0.05unimputed.lods
# 4451.343232676387
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test11
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test11cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test11cutoff0.05unimputed.lods
# 1255.633154168725
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test10
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test10cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test10cutoff0.05unimputed.lods
# 1302.4823306277394
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test9
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test9cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test9cutoff0.05unimputed.lods
# 1768.4950269460678
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test8
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test8cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test8cutoff0.05unimputed.lods
# 2728.166352495551
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test7
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test7cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test7cutoff0.05unimputed.lods
# 1757.9775252267718
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test6
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test6cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test6cutoff0.05unimputed.lods
# 1270.0055547058582
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test5
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test5cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test5cutoff0.05unimputed.lods
# 1197.6981139928102
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test4
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test4cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test4cutoff0.05unimputed.lods
# 557.5677814260125
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test3
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test3cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test3cutoff0.05unimputed.lods
# 779.8307698443532
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test2
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test2cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test2cutoff0.05unimputed.lods
# 1182.7327677235007
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test1
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test1cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test1cutoff0.05unimputed.lods
# 1845.5880765542388
# ../data/wg20220316/chr22test/tmp/CACHE/chr22test0
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test0cutoff0.05unimputed.input
# create input ../data/wg20220316/chr22test/tmp/CACHE/chr22test0cutoff0.05unimputed.lods
# 1756.7208736017346

# %% [markdown]
# ### Genotype of Genes on chr22

# %% [markdown]
# sos run nbs/seqlink_sos.ipynb seqlink --cwd data/wg20220419 --fam_path data/new_trim_ped_famless17_no:xx.fam --vcf_path /mnt/mfs/statgen/alzheimers-family/linkage_files/geno/full_sample/vcf/full_sample.vcf.gz --anno_path MWE/annotation --pop_path data/full_sample_fam_pop.txt --chrom 22 -j 1

# %%
inputs=glob.glob('../data/wg20220419/chr22test/tmp/CACHE/chr22test*.pickle')

# %%
for i in inputs:
    file=i[:-7]
    print(file)
    output=file+'cutoff'+str(cutoff)+'unimputed.input'
    if os.path.isfile(output):
        print('exist! jump',output,file=sys.stderr)
    else:
        print('create input',output,file=sys.stdout)
        with open(file+'.pickle', 'rb') as handle:
            genes = pickle.load(handle)
        gene_variants,gene_fam_haps = format_haps_bunch(genes,fam17_d,fam17_vcf,cutoff,haplotype=False)
        with open(file+'cutoff'+str(cutoff)+'unimputed.input','wb') as handle:
            pickle.dump([gene_variants,gene_fam_haps], handle, protocol=pickle.HIGHEST_PROTOCOL)

    output_file=output[:-6]+'.lods'
    if os.path.isfile(output_file):
        print('exist! jump',output_file,file=sys.stderr)
    else:
        print('create input',output_file,file=sys.stdout)
        with open(output, 'rb') as handle:
            gene_variants,gene_fam_haps = pickle.load(handle) 
        afreqs = []
        for k in gene_fam_haps.keys():
            variants= gene_variants[k]
            variants=variants.freqs[variants.uniq]
            afreqs.append(list(variants.round(decimals=3)))
        res = parallel_lods(gene_fam_haps.values(),afreqs,np.arange(0,0.5,0.05))
        with open(output_file,'wb') as handle:
            pickle.dump(res, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test25
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test25cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test25cutoff0.05unimputed.lods
# 219.76730405539274
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test24
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test24cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test24cutoff0.05unimputed.lods
# 844.886928498745
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test23
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test23cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test23cutoff0.05unimputed.lods
# 5357.9630865082145
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test22
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test22cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test22cutoff0.05unimputed.lods
# 1942.8236759528518
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test21
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test21cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test21cutoff0.05unimputed.lods
# 3690.275728493929
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test20
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test20cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test20cutoff0.05unimputed.lods
# 2007.5318334847689
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test19
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test19cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test19cutoff0.05unimputed.lods
# 915.1901633366942
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test18
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test18cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test18cutoff0.05unimputed.lods
# 1023.5570276752114
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test17
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test17cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test17cutoff0.05unimputed.lods
# 1387.1900959834456
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test16
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test16cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test16cutoff0.05unimputed.lods
# 929.3879333436489
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test15
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test15cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test15cutoff0.05unimputed.lods
# 899.9156624302268
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test14
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test14cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test14cutoff0.05unimputed.lods
# 1727.4548533335328
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test13
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test13cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test13cutoff0.05unimputed.lods
# 4031.973772868514
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test12
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test12cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test12cutoff0.05unimputed.lods
# 2928.735197842121
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test11
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test11cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test11cutoff0.05unimputed.lods
# 1291.893341884017
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test10
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test10cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test10cutoff0.05unimputed.lods
# 1251.6845712587237
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test9
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test9cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test9cutoff0.05unimputed.lods
# 1811.298117659986
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test8
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test8cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test8cutoff0.05unimputed.lods
# 3220.5528910011053
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test7
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test7cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test7cutoff0.05unimputed.lods
# 1276.9674891531467
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test6
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test6cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test6cutoff0.05unimputed.lods
# 1416.8068302050233
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test5
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test5cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test5cutoff0.05unimputed.lods
# 1044.4217685684562
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test4
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test4cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test4cutoff0.05unimputed.lods
# 559.7272296845913
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test3
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test3cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test3cutoff0.05unimputed.lods
# 781.3361460417509
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test2
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test2cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test2cutoff0.05unimputed.lods
# 1201.9214021861553
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test1
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test1cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test1cutoff0.05unimputed.lods
# 1888.6770481616259
# ../data/wg20220419/chr22test/tmp/CACHE/chr22test0
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test0cutoff0.05unimputed.input
# create input ../data/wg20220419/chr22test/tmp/CACHE/chr22test0cutoff0.05unimputed.lods
# 1809.4009956419468

# %% [markdown]
# ### Genotype of whole genome on chr22 (cutoff 0.01)

# %% [markdown]
# sos run nbs/seqlink_sos.ipynb seqlink --cwd data/wg20220421 --fam_path data/new_trim_ped_famless17_no:xx.fam --vcf_path /mnt/mfs/statgen/alzheimers-family/linkage_files/geno/full_sample/vcf/full_sample.vcf.gz --anno_path MWE/annotation --pop_path data/full_sample_fam_pop.txt --chrom 22 -j 1

# %%
inputs=glob.glob('../data/wg20220421/chr22test/tmp/CACHE/chr22test*.pickle')

# %%
cutoff=0.01
for i in inputs:
    file=i[:-7]
    print(file)
    output=file+'cutoff'+str(cutoff)+'unimputed.input'
    if os.path.isfile(output):
        print('exist! jump',output,file=sys.stderr)
    else:
        print('create input',output,file=sys.stdout)
        with open(file+'.pickle', 'rb') as handle:
            genes = pickle.load(handle)
        gene_variants,gene_fam_haps = format_haps_bunch(genes,fam17_d,fam17_vcf,cutoff,haplotype=False)
        with open(file+'cutoff'+str(cutoff)+'unimputed.input','wb') as handle:
            pickle.dump([gene_variants,gene_fam_haps], handle, protocol=pickle.HIGHEST_PROTOCOL)

    output_file=output[:-6]+'.lods'
    if os.path.isfile(output_file):
        print('exist! jump',output_file,file=sys.stderr)
    else:
        print('create input',output_file,file=sys.stdout)
        with open(output, 'rb') as handle:
            gene_variants,gene_fam_haps = pickle.load(handle) 
        afreqs = []
        for k in gene_fam_haps.keys():
            variants= gene_variants[k]
            variants=variants.freqs[variants.uniq]
            afreqs.append(list(variants.round(decimals=3)))
        res = parallel_lods(gene_fam_haps,afreqs,np.arange(0,0.5,0.05))
        with open(output_file,'wb') as handle:
            pickle.dump(res, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# ../data/wg20220421/chr22test/tmp/CACHE/chr22test49
# create input ../data/wg20220421/chr22test/tmp/CACHE/chr22test49cutoff0.01unimputed.lods
# exist! jump ../data/wg20220421/chr22test/tmp/CACHE/chr22test49cutoff0.01unimputed.input
# 2147.93758340925
# ../data/wg20220421/chr22test/tmp/CACHE/chr22test48
# create input ../data/wg20220421/chr22test/tmp/CACHE/chr22test48cutoff0.01unimputed.input
# create input ../data/wg20220421/chr22test/tmp/CACHE/chr22test48cutoff0.01unimputed.lods
# 2686.3592264428735
# ../data/wg20220421/chr22test/tmp/CACHE/chr22test47
# create input ../data/wg20220421/chr22test/tmp/CACHE/chr22test47cutoff0.01unimputed.input
# create input ../data/wg20220421/chr22test/tmp/CACHE/chr22test47cutoff0.01unimputed.lods
# 2700.780797958374
# ../data/wg20220421/chr22test/tmp/CACHE/chr22test46
# create input ../data/wg20220421/chr22test/tmp/CACHE/chr22test46cutoff0.01unimputed.input
# create input ../data/wg20220421/chr22test/tmp/CACHE/chr22test46cutoff0.01unimputed.lods
# 2175.29026068002
# ../data/wg20220421/chr22test/tmp/CACHE/chr22test45
# create input ../data/wg20220421/chr22test/tmp/CACHE/chr22test45cutoff0.01unimputed.input
# create input ../data/wg20220421/chr22test/tmp/CACHE/chr22test45cutoff0.01unimputed.lods
# 1831.7194167524576
# ../data/wg20220421/chr22test/tmp/CACHE/chr22test44
# create input ../data/wg20220421/chr22test/tmp/CACHE/chr22test44cutoff0.01unimputed.input
# create input ../data/wg20220421/chr22test/tmp/CACHE/chr22test44cutoff0.01unimputed.lods
# 2155.2811286076903
# ../data/wg20220421/chr22test/tmp/CACHE/chr22test43
# create input ../data/wg20220421/chr22test/tmp/CACHE/chr22test43cutoff0.01unimputed.input
# create input ../data/wg20220421/chr22test/tmp/CACHE/chr22test43cutoff0.01unimputed.lods
# 2297.093589246273
# ../data/wg20220421/chr22test/tmp/CACHE/chr22test42
# create input ../data/wg20220421/chr22test/tmp/CACHE/chr22test42cutoff0.01unimputed.input
# create input ../data/wg20220421/chr22test/tmp/CACHE/chr22test42cutoff0.01unimputed.lods
# 3910.5350350514054
# ../data/wg20220421/chr22test/tmp/CACHE/chr22test41
# create input ../data/wg20220421/chr22test/tmp/CACHE/chr22test41cutoff0.01unimputed.input
